# %%
import qiime2

# %%
from qiime2 import Visualization

# %%
# Description: What is the influence of genotype (intrinsic) and environment (extrinsic) on anemone-associated bacterial communities?

#Data: Illumina MiSeq v3 paired-end (2 × 300 bp) reads (FASTQ)

#Tools: QIIME 2

#Pipeline: 
#Section 1: Importing, cleaning and quality control of the data
#Section 2: Taxonomic Analysis
#Section 3: Building a phylogenetic tree
#Section 4: Basic visualisations and statistics
#Section 5: Exporting data for further analysis in R

# %%
#https://www.melbournebioinformatics.org.au/tutorials/tutorials/qiime2/qiime2/

# %%
#Section 1: Importing, cleaning and quality control of the data

# %%
#The raw data located in the directory raw_data is exported to a single QIIME 2 artefact file, combined.qza, located in the directory anaylsis/seqs.

# %%
mkdir -p analysis/seqs

# %%
#These sequences still have the primers attached - they need to be removed (using cutadapt) before denoising.

# !qiime cutadapt trim-paired \
--i-demultiplexed-sequences analysis/seqs/combined.qza \
--p-front-f AGGATTAGATACCCTGGTA \
--p-front-r CRRCACGAGCTGACGAC \
--p-error-rate 0.20 \
--output-dir analysis/seqs_trimmed \
--verbose
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The commands to be run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN10_Fwd01-Rev11_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN10_Fwd01-Rev11_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN10_Fwd01-Rev11_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN10_Fwd01-Rev11_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN10_Fwd01-Rev11_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN10_Fwd01-Rev11_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN10_Fwd01-Rev11_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN10_Fwd01-Rev11_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        15,037 reads @  47.7 µs/read;   1.26 M reads/minute
# Finished in 0.731 s (48.622 µs/read; 1.23 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             15,037
#   Read 1 with adapter:                  15,033 (100.0%)
#   Read 2 with adapter:                  15,028 (99.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        15,037 (100.0%)
#
# Total basepairs processed:     8,492,621 bp
#   Read 1:     4,403,058 bp
#   Read 2:     4,089,563 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      7,052,328 bp (83.0%)
#   Read 1:     3,652,876 bp
#   Read 2:     3,399,452 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 15033 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 44	1	0.0	3	1
# 45	1	0.0	3	1
# 46	1	0.0	3	1
# 47	18	0.0	3	15 1 2
# 48	151	0.0	3	106 30 15
# 49	1122	0.0	3	802 310 9 1
# 50	13715	0.0	3	13257 447 11
# 51	23	0.0	3	9 14
# 52	1	0.0	3	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 15028 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 42	3	0.0	3	3
# 43	9	0.0	3	9
# 44	99	0.0	3	61 19 16 3
# 45	955	0.0	3	603 328 22 2
# 46	13947	0.0	3	12740 1173 33 1
# 47	15	0.0	3	10 5
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN22_Fwd02-Rev07_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN22_Fwd02-Rev07_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN22_Fwd02-Rev07_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN22_Fwd02-Rev07_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN22_Fwd02-Rev07_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN22_Fwd02-Rev07_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN22_Fwd02-Rev07_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN22_Fwd02-Rev07_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        15,779 reads @  46.3 µs/read;   1.29 M reads/minute
# Finished in 0.741 s (46.983 µs/read; 1.28 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             15,779
#   Read 1 with adapter:                  15,773 (100.0%)
#   Read 2 with adapter:                  15,759 (99.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   1 (0.0%)
# Pairs written (passing filters):        15,778 (100.0%)
#
# Total basepairs processed:     8,921,169 bp
#   Read 1:     4,632,093 bp
#   Read 2:     4,289,076 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      7,347,475 bp (82.4%)
#   Read 1:     3,829,252 bp
#   Read 2:     3,518,223 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 15773 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 43	1	0.0	3	1
# 44	1	0.0	3	1
# 46	3	0.0	3	3
# 47	9	0.0	3	7 1 0 1
# 48	29	0.0	3	23 3 2 1
# 49	170	0.0	3	132 23 15
# 50	1376	0.0	3	1042 328 6
# 51	14152	0.0	3	13664 478 9 1
# 52	27	0.0	3	12 14 1
# 53	5	0.0	3	5
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 15759 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 37	1	0.0	3	0 0 0 1
# 43	3	0.0	3	1 1 0 1
# 44	3	0.0	3	1 2
# 45	4	0.0	3	1 3
# 46	20	0.0	3	12 5 1 2
# 47	99	0.0	3	62 17 19 1
# 48	1075	0.0	3	729 332 12 2
# 49	14513	0.0	3	14047 436 20 10
# 50	26	0.0	3	12 14
# 51	15	0.0	3	15
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN27_Fwd02-Rev13_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN27_Fwd02-Rev13_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN27_Fwd02-Rev13_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN27_Fwd02-Rev13_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN27_Fwd02-Rev13_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN27_Fwd02-Rev13_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN27_Fwd02-Rev13_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN27_Fwd02-Rev13_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        13,612 reads @  47.2 µs/read;   1.27 M reads/minute
# Finished in 0.650 s (47.770 µs/read; 1.26 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             13,612
#   Read 1 with adapter:                  13,609 (100.0%)
#   Read 2 with adapter:                  13,597 (99.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        13,612 (100.0%)
#
# Total basepairs processed:     7,704,804 bp
#   Read 1:     4,017,738 bp
#   Read 2:     3,687,066 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      6,374,606 bp (82.7%)
#   Read 1:     3,325,259 bp
#   Read 2:     3,049,347 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 13609 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 40	1	0.0	3	1
# 44	1	0.0	3	1
# 46	2	0.0	3	1 0 0 1
# 47	6	0.0	3	6
# 48	25	0.0	3	19 3 2 1
# 49	158	0.0	3	114 26 17 1
# 50	1176	0.0	3	864 305 6 1
# 51	12210	0.0	3	11778 421 11
# 52	21	0.0	3	10 10 1
# 53	9	0.0	3	9
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 13597 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 41	1	0.0	3	0 0 1
# 42	1	0.0	3	1
# 43	2	0.0	3	2
# 44	22	0.0	3	12 5 3 2
# 45	110	0.0	3	67 23 19 1
# 46	1057	0.0	3	726 322 9
# 47	12382	0.0	3	11987 364 27 4
# 48	22	0.0	3	7 14 1
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN40_Fwd03-Rev04_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN40_Fwd03-Rev04_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN40_Fwd03-Rev04_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN40_Fwd03-Rev04_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN40_Fwd03-Rev04_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN40_Fwd03-Rev04_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN40_Fwd03-Rev04_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN40_Fwd03-Rev04_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        14,611 reads @  47.2 µs/read;   1.27 M reads/minute
# Finished in 0.699 s (47.842 µs/read; 1.25 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             14,611
#   Read 1 with adapter:                  14,603 (99.9%)
#   Read 2 with adapter:                  14,597 (99.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        14,611 (100.0%)
#
# Total basepairs processed:     8,201,693 bp
#   Read 1:     4,238,121 bp
#   Read 2:     3,963,572 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      6,773,588 bp (82.6%)
#   Read 1:     3,480,226 bp
#   Read 2:     3,293,362 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 14603 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 42	1	0.0	3	1
# 43	1	0.0	3	1
# 45	1	0.0	3	1
# 47	2	0.0	3	2
# 48	5	0.0	3	5
# 49	18	0.0	3	16 2
# 50	119	0.0	3	85 21 13
# 51	1135	0.0	3	823 293 16 3
# 52	13299	0.0	3	12827 450 19 3
# 53	22	0.0	3	9 13
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 14597 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 39	1	0.0	3	1
# 41	2	0.0	3	2
# 42	3	0.0	3	2 0 1
# 43	15	0.0	3	8 3 2 2
# 44	96	0.0	3	57 23 15 1
# 45	1007	0.0	3	646 341 20
# 46	13454	0.0	3	12349 1074 29 2
# 47	18	0.0	3	9 6 2 1
# 49	1	0.0	3	0 0 0 1
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN45_Fwd03-Rev09_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN45_Fwd03-Rev09_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN45_Fwd03-Rev09_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN45_Fwd03-Rev09_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN45_Fwd03-Rev09_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN45_Fwd03-Rev09_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN45_Fwd03-Rev09_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN45_Fwd03-Rev09_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        18,187 reads @  48.5 µs/read;   1.24 M reads/minute
# Finished in 0.894 s (49.179 µs/read; 1.22 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             18,187
#   Read 1 with adapter:                  18,179 (100.0%)
#   Read 2 with adapter:                  18,175 (99.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        18,187 (100.0%)
#
# Total basepairs processed:    10,199,573 bp
#   Read 1:     5,281,703 bp
#   Read 2:     4,917,870 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      8,421,508 bp (82.6%)
#   Read 1:     4,338,153 bp
#   Read 2:     4,083,355 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 18179 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 44	2	0.0	3	1 1
# 45	1	0.0	3	1
# 47	2	0.0	3	2
# 48	6	0.0	3	5 1
# 49	21	0.0	3	15 2 2 2
# 50	167	0.0	3	120 31 15 1
# 51	1337	0.0	3	965 360 9 3
# 52	16610	0.0	3	15951 627 26 6
# 53	33	0.0	3	12 20 1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 18175 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 40	1	0.0	3	1
# 41	1	0.0	3	1
# 42	8	0.0	3	6 1 0 1
# 43	15	0.0	3	10 3 1 1
# 44	126	0.0	3	77 26 22 1
# 45	1213	0.0	3	732 451 28 2
# 46	16793	0.0	3	15174 1570 45 4
# 47	18	0.0	3	8 9 1
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN48_Fwd03-Rev13_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN48_Fwd03-Rev13_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN48_Fwd03-Rev13_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN48_Fwd03-Rev13_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN48_Fwd03-Rev13_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN48_Fwd03-Rev13_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN48_Fwd03-Rev13_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN48_Fwd03-Rev13_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        14,083 reads @  47.1 µs/read;   1.27 M reads/minute
# Finished in 0.676 s (48.026 µs/read; 1.25 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             14,083
#   Read 1 with adapter:                  14,082 (100.0%)
#   Read 2 with adapter:                  14,078 (100.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        14,083 (100.0%)
#
# Total basepairs processed:     7,917,605 bp
#   Read 1:     4,083,833 bp
#   Read 2:     3,833,772 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      6,526,471 bp (82.4%)
#   Read 1:     3,352,980 bp
#   Read 2:     3,173,491 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 14082 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 43	1	0.0	3	0 1
# 46	1	0.0	3	1
# 47	1	0.0	3	1
# 48	4	0.0	3	2 1 1
# 49	22	0.0	3	20 1 0 1
# 50	139	0.0	3	91 24 24
# 51	1056	0.0	3	758 285 12 1
# 52	12833	0.0	3	12368 441 20 4
# 53	25	0.0	3	17 8
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 14078 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 39	1	0.0	3	1
# 43	5	0.0	3	3 2
# 44	16	0.0	3	13 0 1 2
# 45	91	0.0	3	51 26 14
# 46	1143	0.0	3	803 334 5 1
# 47	12806	0.0	3	12464 329 11 2
# 48	16	0.0	3	7 9
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN58_Fwd04-Rev11_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN58_Fwd04-Rev11_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN58_Fwd04-Rev11_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN58_Fwd04-Rev11_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN58_Fwd04-Rev11_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN58_Fwd04-Rev11_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN58_Fwd04-Rev11_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN58_Fwd04-Rev11_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        11,780 reads @  56.2 µs/read;   1.07 M reads/minute
# Finished in 0.668 s (56.740 µs/read; 1.06 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             11,780
#   Read 1 with adapter:                  11,775 (100.0%)
#   Read 2 with adapter:                  11,772 (99.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        11,780 (100.0%)
#
# Total basepairs processed:     6,693,438 bp
#   Read 1:     3,490,418 bp
#   Read 2:     3,203,020 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      5,577,039 bp (83.3%)
#   Read 1:     2,914,555 bp
#   Read 2:     2,662,484 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 11775 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 42	1	0.0	3	1
# 44	1	0.0	3	1
# 45	1	0.0	3	1
# 46	8	0.0	3	7 0 0 1
# 47	94	0.0	3	71 14 9
# 48	900	0.0	3	632 259 8 1
# 49	10754	0.0	3	10438 309 6 1
# 50	16	0.0	3	6 10
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 11772 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 40	1	0.0	3	1
# 41	2	0.0	3	0 1 1
# 42	1	0.0	3	1
# 43	19	0.0	3	12 3 2 2
# 44	72	0.0	3	43 15 14
# 45	778	0.0	3	469 284 23 2
# 46	10876	0.0	3	9887 965 20 4
# 47	23	0.0	3	9 11 3
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN66_Fwd05-Rev06_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN66_Fwd05-Rev06_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN66_Fwd05-Rev06_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN66_Fwd05-Rev06_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN66_Fwd05-Rev06_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN66_Fwd05-Rev06_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN66_Fwd05-Rev06_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN66_Fwd05-Rev06_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        10,771 reads @  49.4 µs/read;   1.22 M reads/minute
# Finished in 0.539 s (50.068 µs/read; 1.20 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             10,771
#   Read 1 with adapter:                  10,771 (100.0%)
#   Read 2 with adapter:                  10,766 (100.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        10,771 (100.0%)
#
# Total basepairs processed:     6,130,130 bp
#   Read 1:     3,201,175 bp
#   Read 2:     2,928,955 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      5,098,656 bp (83.2%)
#   Read 1:     2,663,936 bp
#   Read 2:     2,434,720 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 10771 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	6	168.3	0	6
# 45	2	0.0	3	1 0 0 1
# 46	2	0.0	3	2
# 47	8	0.0	3	6 1 0 1
# 48	92	0.0	3	68 9 15
# 49	812	0.0	3	602 207 3
# 50	9840	0.0	3	9578 253 9
# 51	9	0.0	3	6 3
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 10766 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 32	1	0.0	3	0 1
# 42	4	0.0	3	2 2
# 43	12	0.0	3	8 3 1
# 44	71	0.0	3	45 14 10 2
# 45	804	0.0	3	513 268 23
# 46	9863	0.0	3	8909 917 32 5
# 47	11	0.0	3	6 5
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN67_Fwd05-Rev07_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN67_Fwd05-Rev07_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN67_Fwd05-Rev07_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN67_Fwd05-Rev07_L001_R2_001.fastq.gz
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN67_Fwd05-Rev07_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN67_Fwd05-Rev07_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN67_Fwd05-Rev07_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN67_Fwd05-Rev07_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        12,855 reads @  45.3 µs/read;   1.32 M reads/minute
# Finished in 0.589 s (45.843 µs/read; 1.31 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             12,855
#   Read 1 with adapter:                  12,855 (100.0%)
#   Read 2 with adapter:                  12,844 (99.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        12,855 (100.0%)
#
# Total basepairs processed:     7,323,659 bp
#   Read 1:     3,823,404 bp
#   Read 2:     3,500,255 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      6,054,113 bp (82.7%)
#   Read 1:     3,182,141 bp
#   Read 2:     2,871,972 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 12855 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	4	200.9	0	4
# 36	1	0.0	3	1
# 45	4	0.0	3	3 1
# 46	3	0.0	3	2 0 1
# 47	18	0.0	3	14 2 1 1
# 48	115	0.0	3	88 18 7 2
# 49	1000	0.0	3	724 273 3
# 50	11690	0.0	3	11396 286 7 1
# 51	19	0.0	3	8 11
# 62	1	0.0	3	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 12844 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 42	2	0.0	3	1 0 0 1
# 44	3	0.0	3	3
# 45	4	0.0	3	4
# 46	19	0.0	3	10 8 1
# 47	92	0.0	3	58 19 15
# 48	845	0.0	3	565 276 4
# 49	11835	0.0	3	11493 319 17 6
# 50	30	0.0	3	13 16 1
# 51	14	0.0	3	14
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN70_Fwd05-Rev11_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN70_Fwd05-Rev11_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN70_Fwd05-Rev11_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN70_Fwd05-Rev11_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN70_Fwd05-Rev11_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN70_Fwd05-Rev11_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN70_Fwd05-Rev11_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN70_Fwd05-Rev11_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        14,758 reads @  46.1 µs/read;   1.30 M reads/minute
# Finished in 0.692 s (46.912 µs/read; 1.28 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             14,758
#   Read 1 with adapter:                  14,758 (100.0%)
#   Read 2 with adapter:                  14,751 (100.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        14,758 (100.0%)
#
# Total basepairs processed:     8,396,339 bp
#   Read 1:     4,391,100 bp
#   Read 2:     4,005,239 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      6,982,763 bp (83.2%)
#   Read 1:     3,654,764 bp
#   Read 2:     3,327,999 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 14758 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	4	230.6	0	4
# 42	1	0.0	3	1
# 43	1	0.0	3	1
# 46	2	0.0	3	2
# 47	9	0.0	3	8 1
# 48	119	0.0	3	85 22 12
# 49	1111	0.0	3	814 289 8
# 50	13488	0.0	3	13126 352 10
# 51	23	0.0	3	13 9 1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 14751 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 40	2	0.0	3	2
# 42	5	0.0	3	2 0 3
# 43	16	0.0	3	8 2 4 2
# 44	103	0.0	3	59 19 22 3
# 45	1047	0.0	3	655 358 32 2
# 46	13551	0.0	3	12252 1253 42 4
# 47	27	0.0	3	11 14 2
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN73_Fwd06-Rev01_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN73_Fwd06-Rev01_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN73_Fwd06-Rev01_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN73_Fwd06-Rev01_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN73_Fwd06-Rev01_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN73_Fwd06-Rev01_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN73_Fwd06-Rev01_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN73_Fwd06-Rev01_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:01        16,806 reads @  67.8 µs/read;   0.88 M reads/minute
# Finished in 1.150 s (68.433 µs/read; 0.88 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             16,806
#   Read 1 with adapter:                  16,803 (100.0%)
#   Read 2 with adapter:                  16,791 (99.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        16,806 (100.0%)
#
# Total basepairs processed:     9,535,637 bp
#   Read 1:     4,989,031 bp
#   Read 2:     4,546,606 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      7,926,246 bp (83.1%)
#   Read 1:     4,167,349 bp
#   Read 2:     3,758,897 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 16803 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 44	2	0.0	3	1 0 0 1
# 45	8	0.0	3	7 0 0 1
# 46	21	0.0	3	17 1 2 1
# 47	119	0.0	3	88 19 12
# 48	1344	0.0	3	962 374 7 1
# 49	15287	0.0	3	14810 458 16 3
# 50	22	0.0	3	13 9
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 16791 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 39	1	0.0	3	1
# 41	3	0.0	3	1 0 2
# 42	2	0.0	3	0 1 1
# 43	2	0.0	3	2
# 44	17	0.0	3	11 3 2 1
# 45	111	0.0	3	75 22 13 1
# 46	1205	0.0	3	778 417 10
# 47	15432	0.0	3	14979 415 31 7
# 48	17	0.0	3	9 8
# 84	1	0.0	3	1
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN74_Fwd06-Rev02_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN74_Fwd06-Rev02_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN74_Fwd06-Rev02_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN74_Fwd06-Rev02_L001_R2_001.fastq.gz
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN74_Fwd06-Rev02_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN74_Fwd06-Rev02_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN74_Fwd06-Rev02_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN74_Fwd06-Rev02_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        12,482 reads @  50.5 µs/read;   1.19 M reads/minute
# Finished in 0.642 s (51.470 µs/read; 1.17 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             12,482
#   Read 1 with adapter:                  12,479 (100.0%)
#   Read 2 with adapter:                  12,471 (99.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        12,482 (100.0%)
#
# Total basepairs processed:     7,060,330 bp
#   Read 1:     3,693,930 bp
#   Read 2:     3,366,400 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      5,852,590 bp (82.9%)
#   Read 1:     3,083,664 bp
#   Read 2:     2,768,926 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 12479 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 35	1	0.0	3	1
# 45	5	0.0	3	4 0 1
# 46	14	0.0	3	11 1 0 2
# 47	114	0.0	3	83 21 10
# 48	919	0.0	3	656 251 12
# 49	11409	0.0	3	11052 345 12
# 50	16	0.0	3	9 7
# 51	1	0.0	3	0 1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 12471 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 42	1	0.0	3	0 0 0 1
# 43	3	0.0	3	1 2
# 44	3	0.0	3	1 1 0 1
# 45	12	0.0	3	9 2 1
# 46	104	0.0	3	58 34 12
# 47	877	0.0	3	563 306 7 1
# 48	11451	0.0	3	11080 347 16 8
# 49	20	0.0	3	6 14
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN76_Fwd06-Rev04_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN76_Fwd06-Rev04_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN76_Fwd06-Rev04_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN76_Fwd06-Rev04_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN76_Fwd06-Rev04_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN76_Fwd06-Rev04_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN76_Fwd06-Rev04_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN76_Fwd06-Rev04_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        16,818 reads @  49.2 µs/read;   1.22 M reads/minute
# Finished in 0.835 s (49.664 µs/read; 1.21 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             16,818
#   Read 1 with adapter:                  16,816 (100.0%)
#   Read 2 with adapter:                  16,811 (100.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        16,818 (100.0%)
#
# Total basepairs processed:     9,537,344 bp
#   Read 1:     4,991,017 bp
#   Read 2:     4,546,327 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      7,943,168 bp (83.3%)
#   Read 1:     4,168,651 bp
#   Read 2:     3,774,517 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 16816 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 44	3	0.0	3	2 0 0 1
# 45	3	0.0	3	2 0 1
# 46	22	0.0	3	17 1 3 1
# 47	144	0.0	3	98 28 18
# 48	1259	0.0	3	868 378 10 3
# 49	15364	0.0	3	14901 451 9 3
# 50	20	0.0	3	7 13
# 51	1	0.0	3	0 1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 16811 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 38	1	0.0	3	0 1
# 42	4	0.0	3	4
# 43	12	0.0	3	10 0 2
# 44	131	0.0	3	71 28 30 2
# 45	1185	0.0	3	786 368 28 3
# 46	15467	0.0	3	14004 1413 39 11
# 47	11	0.0	3	5 4 2
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN77_Fwd06-Rev05_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN77_Fwd06-Rev05_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN77_Fwd06-Rev05_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN77_Fwd06-Rev05_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN77_Fwd06-Rev05_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN77_Fwd06-Rev05_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN77_Fwd06-Rev05_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN77_Fwd06-Rev05_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:01        18,675 reads @  56.6 µs/read;   1.06 M reads/minute
# Finished in 1.065 s (57.040 µs/read; 1.05 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             18,675
#   Read 1 with adapter:                  18,672 (100.0%)
#   Read 2 with adapter:                  18,663 (99.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        18,675 (100.0%)
#
# Total basepairs processed:    10,611,252 bp
#   Read 1:     5,543,297 bp
#   Read 2:     5,067,955 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      8,822,780 bp (83.1%)
#   Read 1:     4,630,216 bp
#   Read 2:     4,192,564 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 18672 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 40	1	0.0	3	1
# 44	2	0.0	3	2
# 45	3	0.0	3	3
# 46	26	0.0	3	18 5 3
# 47	156	0.0	3	117 24 15
# 48	1462	0.0	3	1039 412 9 2
# 49	16986	0.0	3	16493 480 13
# 50	36	0.0	3	22 14
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 18663 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 36	1	0.0	3	0 0 0 1
# 37	1	0.0	3	1
# 41	1	0.0	3	1
# 42	2	0.0	3	2
# 43	3	0.0	3	2 0 1
# 44	22	0.0	3	15 4 0 3
# 45	148	0.0	3	90 33 24 1
# 46	1378	0.0	3	910 453 14 1
# 47	17088	0.0	3	16531 523 25 9
# 48	19	0.0	3	4 15
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN78_Fwd06-Rev06_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN78_Fwd06-Rev06_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN78_Fwd06-Rev06_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN78_Fwd06-Rev06_L001_R2_001.fastq.gz
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN78_Fwd06-Rev06_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN78_Fwd06-Rev06_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN78_Fwd06-Rev06_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN78_Fwd06-Rev06_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        16,591 reads @  57.7 µs/read;   1.04 M reads/minute
# Finished in 0.967 s (58.311 µs/read; 1.03 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             16,591
#   Read 1 with adapter:                  16,583 (100.0%)
#   Read 2 with adapter:                  16,581 (99.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        16,591 (100.0%)
#
# Total basepairs processed:     9,402,592 bp
#   Read 1:     4,923,673 bp
#   Read 2:     4,478,919 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
# ...
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN94_Fwd07-Rev11_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN94_Fwd07-Rev11_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN94_Fwd07-Rev11_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN94_Fwd07-Rev11_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        10,511 reads @  55.4 µs/read;   1.08 M reads/minute
# Finished in 0.595 s (56.635 µs/read; 1.06 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             10,511
#   Read 1 with adapter:                  10,507 (100.0%)
#   Read 2 with adapter:                  10,508 (100.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        10,511 (100.0%)
#
# Total basepairs processed:     5,962,516 bp
#   Read 1:     3,105,377 bp
#   Read 2:     2,857,139 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      4,934,993 bp (82.8%)
#   Read 1:     2,560,224 bp
#   Read 2:     2,374,769 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 10507 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 41	1	0.0	3	1
# 47	2	0.0	3	2
# 48	6	0.0	3	5 0 1
# 49	26	0.0	3	22 2 2
# 50	106	0.0	3	79 16 11
# 51	890	0.0	3	642 242 6
# 52	9462	0.0	3	9173 280 8 1
# 53	14	0.0	3	6 8
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 10508 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 20	1	0.0	3	0 0 0 1
# 42	4	0.0	3	3 0 1
# 43	12	0.0	3	7 2 3
# 44	88	0.0	3	58 20 8 2
# 45	758	0.0	3	481 264 13
# 46	9631	0.0	3	8725 881 23 2
# 47	14	0.0	3	9 5
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN95_Fwd07-Rev12_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN95_Fwd07-Rev12_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN95_Fwd07-Rev12_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN95_Fwd07-Rev12_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN95_Fwd07-Rev12_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/AN95_Fwd07-Rev12_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN95_Fwd07-Rev12_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/AN95_Fwd07-Rev12_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00         9,157 reads @  52.3 µs/read;   1.15 M reads/minute
# Finished in 0.490 s (53.535 µs/read; 1.12 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:              9,157
#   Read 1 with adapter:                   9,154 (100.0%)
#   Read 2 with adapter:                   9,152 (99.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):         9,157 (100.0%)
#
# Total basepairs processed:     5,202,962 bp
#   Read 1:     2,707,344 bp
#   Read 2:     2,495,618 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      4,289,366 bp (82.4%)
#   Read 1:     2,232,366 bp
#   Read 2:     2,057,000 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 9154 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 42	1	0.0	3	1
# 46	1	0.0	3	1
# 47	2	0.0	3	1 0 0 1
# 48	1	0.0	3	1
# 49	16	0.0	3	13 3
# 50	92	0.0	3	64 16 11 1
# 51	780	0.0	3	570 202 8
# 52	8249	0.0	3	7984 263 2
# 53	12	0.0	3	7 4 1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 9152 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 44	1	0.0	3	0 0 0 1
# 45	11	0.0	3	3 4 0 4
# 46	38	0.0	3	14 17 7
# 47	578	0.0	3	358 211 7 2
# 48	8511	0.0	3	8258 239 10 4
# 49	13	0.0	3	4 9
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/CTRLA_Fwd04-Rev25_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/CTRLA_Fwd04-Rev25_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/CTRLA_Fwd04-Rev25_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/CTRLA_Fwd04-Rev25_L001_R2_001.fastq.gz
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/CTRLA_Fwd04-Rev25_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/CTRLA_Fwd04-Rev25_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/CTRLA_Fwd04-Rev25_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/CTRLA_Fwd04-Rev25_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        11,121 reads @  45.1 µs/read;   1.33 M reads/minute
# Finished in 0.511 s (45.928 µs/read; 1.31 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             11,121
#   Read 1 with adapter:                  11,117 (100.0%)
#   Read 2 with adapter:                  11,117 (100.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        11,121 (100.0%)
#
# Total basepairs processed:     6,315,505 bp
#   Read 1:     3,294,318 bp
#   Read 2:     3,021,187 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      5,249,934 bp (83.1%)
#   Read 1:     2,750,638 bp
#   Read 2:     2,499,296 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 11117 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 41	1	0.0	3	1
# 44	1	0.0	3	1
# 45	1	0.0	3	0 0 1
# 46	9	0.0	3	6 1 2
# 47	106	0.0	3	69 21 16
# 48	821	0.0	3	572 232 14 3
# 49	10154	0.0	3	9726 413 15
# 50	24	0.0	3	7 17
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 11117 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 36	1	0.0	3	1
# 41	1	0.0	3	1
# 42	2	0.0	3	2
# 43	2	0.0	3	1 0 0 1
# 44	6	0.0	3	3 1 1 1
# 45	45	0.0	3	21 14 10
# 46	490	0.0	3	230 247 13
# 47	10546	0.0	3	10108 421 16 1
# 48	23	0.0	3	16 7
# 49	1	0.0	3	1
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/CTRLB_Fwd04-Rev27_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/CTRLB_Fwd04-Rev27_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/CTRLB_Fwd04-Rev27_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/CTRLB_Fwd04-Rev27_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/CTRLB_Fwd04-Rev27_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/CTRLB_Fwd04-Rev27_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/CTRLB_Fwd04-Rev27_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/CTRLB_Fwd04-Rev27_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00         7,349 reads @  47.3 µs/read;   1.27 M reads/minute
# Finished in 0.361 s (49.110 µs/read; 1.22 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:              7,349
#   Read 1 with adapter:                   7,346 (100.0%)
#   Read 2 with adapter:                   7,341 (99.9%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):         7,349 (100.0%)
#
# Total basepairs processed:     4,132,742 bp
#   Read 1:     2,158,990 bp
#   Read 2:     1,973,752 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      3,428,897 bp (83.0%)
#   Read 1:     1,799,721 bp
#   Read 2:     1,629,176 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 7346 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 44	1	0.0	3	1
# 45	1	0.0	3	1
# 46	7	0.0	3	3 2 1 1
# 47	55	0.0	3	40 8 6 1
# 48	558	0.0	3	381 174 3
# 49	6711	0.0	3	6471 235 5
# 50	13	0.0	3	7 6
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 7341 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 36	1	0.0	3	1
# 42	1	0.0	3	0 1
# 43	3	0.0	3	2 1
# 44	2	0.0	3	0 1 0 1
# 45	35	0.0	3	9 14 12
# 46	367	0.0	3	215 146 4 2
# 47	6914	0.0	3	6665 228 19 2
# 48	16	0.0	3	10 6
# 49	2	0.0	3	2
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/CTRLC_Fwd04-Rev28_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/CTRLC_Fwd04-Rev28_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/CTRLC_Fwd04-Rev28_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/CTRLC_Fwd04-Rev28_L001_R2_001.fastq.gz
#
# This is cutadapt 4.5 with Python 3.8.18
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/CTRLC_Fwd04-Rev28_L001_R1_001.fastq.gz -p /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-dlak_tqs/CTRLC_Fwd04-Rev28_L001_R2_001.fastq.gz --front AGGATTAGATACCCTGGTA -G CRRCACGAGCTGACGAC /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/CTRLC_Fwd04-Rev28_L001_R1_001.fastq.gz /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f28e9851-b0cc-49eb-95b3-0e8ee9c90fe4/data/CTRLC_Fwd04-Rev28_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        13,122 reads @  50.7 µs/read;   1.18 M reads/minute
# Finished in 0.675 s (51.421 µs/read; 1.17 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             13,122
#   Read 1 with adapter:                  13,122 (100.0%)
#   Read 2 with adapter:                  13,122 (100.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        13,122 (100.0%)
#
# Total basepairs processed:     7,373,732 bp
#   Read 1:     3,851,377 bp
#   Read 2:     3,522,355 bp
# Quality-trimmed:                       0 bp (0.0%)
#   Read 1:             0 bp
#   Read 2:             0 bp
# Total written (filtered):      6,116,544 bp (83.0%)
#   Read 1:     3,209,659 bp
#   Read 2:     2,906,885 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGATTAGATACCCTGGTA; Type: regular 5'; Length: 19; Trimmed: 13122 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 43	1	0.0	3	1
# 45	1	0.0	3	1
# 46	19	0.0	3	14 3 0 2
# 47	99	0.0	3	62 21 16
# 48	1012	0.0	3	705 298 7 2
# 49	11973	0.0	3	11512 443 17 1
# 50	17	0.0	3	4 12 1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CRRCACGAGCTGACGAC; Type: regular 5'; Length: 17; Trimmed: 13122 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-17 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 5	12	12.8	1	0 12
# 37	1	0.0	3	1
# 41	3	0.0	3	2 1
# 42	4	0.0	3	3 1
# 43	9	0.0	3	6 3
# 44	7	0.0	3	5 0 1 1
# 45	40	0.0	3	14 12 12 2
# 46	594	0.0	3	287 296 9 2
# 47	12433	0.0	3	11954 458 18 3
# 48	19	0.0	3	14 5
# Saved SampleData[PairedEndSequencesWithQuality] to: analysis/seqs_trimmed/trimmed_sequences.qza

# %%
mkdir analysis/visualisations

# %%
#Create a viewable summary file so the data quality can be checked. Viewing the quality plots generated here helps determine trim settings.
# !qiime demux summarize \
--i-data analysis/seqs_trimmed/trimmed_sequences.qza \
--o-visualization analysis/visualisations/trimmed_sequences.qzv
# Out:
# Saved Visualization to: analysis/visualisations/trimmed_sequences.qzv

# %%
# Load and display visualization for trimmed sequences
path_to_trimmed_sequences_qzv = 'analysis/visualisations/trimmed_sequences.qzv'
visualization_trimmed_sequences = Visualization.load(path_to_trimmed_sequences_qzv)
display(visualization_trimmed_sequences)
# Out:
# <visualization: Visualization uuid: 9d0d6f21-4397-4387-ad83-2b146eed1250>

# %%
#Denoising the data
#Trimmed sequences are now quality assessed using the dada2 plugin within QIIME2.

# %%
# !qiime dada2 denoise-paired \
--i-demultiplexed-seqs analysis/seqs_trimmed/trimmed_sequences.qza \
--p-trunc-len-f 180 \
--p-trunc-len-r 160 \
--p-n-threads 0 \
--output-dir analysis/dada2out \
--verbose
# Out:
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada.R --input_directory /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/tmp23gn9uqa/forward --input_directory_reverse /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/tmp23gn9uqa/reverse --output_path /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/tmp23gn9uqa/output.tsv.biom --output_track /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/tmp23gn9uqa/track.tsv --filtered_directory /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/tmp23gn9uqa/filt_f --filtered_directory_reverse /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/tmp23gn9uqa/filt_r --truncation_length 180 --truncation_length_reverse 160 --trim_left 0 --trim_left_reverse 0 --max_expected_errors 2.0 --max_expected_errors_reverse 2.0 --truncation_quality_score 2 --min_overlap 12 --pooling_method independent --chimera_method consensus --min_parental_fold 1.0 --allow_one_off False --num_threads 0 --learn_min_reads 1000000
#
# Warning message:
# package ‘optparse’ was built under R version 4.2.3
# R version 4.2.2 (2022-10-31)
# Loading required package: Rcpp
# DADA2: 1.26.0 / Rcpp: 1.0.11 / RcppParallel: 5.1.6
# 2) Filtering .......................
# 3) Learning Error Rates
# 49439340 total bases in 274663 reads from 23 samples will be used for learning the error rates.
# 43946080 total bases in 274663 reads from 23 samples will be used for learning the error rates.
# 3) Denoise samples .......................
# .......................
# 5) Remove chimeras (method = consensus)
# 6) Report read numbers through the pipeline
# 7) Write output
# Saved FeatureTable[Frequency] to: analysis/dada2out/table.qza
# Saved FeatureData[Sequence] to: analysis/dada2out/representative_sequences.qza
# Saved SampleData[DADA2Stats] to: analysis/dada2out/denoising_stats.qza

# %%
#Generate summary files

# %%
# !qiime metadata tabulate \
--m-input-file analysis/dada2out/denoising_stats.qza \
--o-visualization analysis/visualisations/16s_denoising_stats.qzv \
--verbose
# Out:
# Saved Visualization to: analysis/visualisations/16s_denoising_stats.qzv

# %%
path_to_16s_denoising_stats_qzv = 'analysis/visualisations/16s_denoising_stats.qzv'
visualization_16s_denoising_stats = Visualization.load(path_to_16s_denoising_stats_qzv)
display(visualization_16s_denoising_stats)
# Out:
# <visualization: Visualization uuid: 4ea33aa8-f8b0-4c25-b431-da6d350381c5>

# %%
# !qiime feature-table summarize \
--i-table analysis/dada2out/table.qza \
--m-sample-metadata-file data_files/metadata.tsv \
--o-visualization analysis/visualisations/16s_table.qzv \
--verbose
# Out:
# Saved Visualization to: analysis/visualisations/16s_table.qzv

# %%
path_to_16s_table_qzv = 'analysis/visualisations/16s_table.qzv'
visualization_16s_table = Visualization.load(path_to_16s_table_qzv)
display(visualization_16s_table)
# Out:
# <visualization: Visualization uuid: 28a1e094-ef6c-4754-aaf8-abb79e06d665>

# %%
# !qiime feature-table tabulate-seqs \
--i-data analysis/dada2out/representative_sequences.qza \
--o-visualization analysis/visualisations/16s_representative_seqs.qzv \
--verbose
# Out:
# Saved Visualization to: analysis/visualisations/16s_representative_seqs.qzv

# %%
path_to_16s_representative_seqs_qzv = 'analysis/visualisations/16s_representative_seqs.qzv'
visualization_16s_representative_seqs = Visualization.load(path_to_16s_representative_seqs_qzv)
display(visualization_16s_representative_seqs)
# Out:
# <visualization: Visualization uuid: ea369f20-2a74-4e5e-b48a-dc0443eee9c9>

# %%
#Section 2: Taxonomic Analysis¶
#Assign taxonomy
#classify each identical read or Amplicon Sequence Variant (ASV) to the highest resolution based on a database.
#A classifier has already been trained for you for the V5V6 region of the bacterial 16S rRNA gene using the SILVA database.

# %%
# !qiime feature-classifier classify-sklearn \
--i-classifier silva_138_16s_v5v6_classifier_2021-4.qza \
--i-reads analysis/dada2out/representative_sequences.qza \
--p-n-jobs 1 \
--output-dir analysis/taxonomy \
--verbose
# Out:
# Saved FeatureData[Taxonomy] to: analysis/taxonomy/classification.qza

# %%
#Generate a viewable summary file of the taxonomic assignments.

# %%
# !qiime metadata tabulate \
--m-input-file analysis/taxonomy/classification.qza \
--o-visualization analysis/visualisations/taxonomy.qzv \
--verbose
# Out:
# Saved Visualization to: analysis/visualisations/taxonomy.qzv

# %%
#Filtering
#Generate a viewable summary file of the new table to see the effect of filtering.

# %%
# !qiime taxa filter-table \
--i-table analysis/dada2out/table.qza \
--i-taxonomy analysis/taxonomy/classification.qza  \
--p-exclude Mitochondria,Chloroplast \
--o-filtered-table analysis/taxonomy/16s_table_filtered.qza \
--verbose
# Out:
# Saved FeatureTable[Frequency] to: analysis/taxonomy/16s_table_filtered.qza

# %%
# !qiime feature-table summarize \
--i-table analysis/taxonomy/16s_table_filtered.qza \
--m-sample-metadata-file data_files/metadata.tsv \
--o-visualization analysis/visualisations/16s_table_filtered.qzv \
--verbose
# Out:
# Saved Visualization to: analysis/visualisations/16s_table_filtered.qzv

# %%
path_to_16s_table_filtered_qzv = 'analysis/visualisations/16s_table_filtered.qzv'
visualization_16s_table_filtered = Visualization.load(path_to_16s_table_filtered_qzv)
display(visualization_16s_table_filtered)
# Out:
# <visualization: Visualization uuid: 30e05cbe-9ba0-49fe-8ac8-35912600f9fd>

# %%
#Section 3: Build a phylogenetic tree¶

# %%
# !qiime phylogeny align-to-tree-mafft-fasttree \
--i-sequences analysis/dada2out/representative_sequences.qza \
--o-alignment analysis/tree/aligned_16s_representative_seqs.qza \
--o-masked-alignment analysis/tree/masked_aligned_16s_representative_seqs.qza \
--o-tree analysis/tree/16s_unrooted_tree.qza \
--o-rooted-tree analysis/tree/16s_rooted_tree.qza \
--p-n-threads 1 \
--verbose
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: mafft --preservecase --inputorder --thread 1 /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/2aca41e4-4608-4f6b-8f17-bd396521c188/data/dna-sequences.fasta
#
# inputfile = orig
# 700 x 289 - 240 d
# nthread = 1
# nthreadpair = 1
# nthreadtb = 1
# ppenalty_ex = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#   601 / 700 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   690 / 700
# done.
#
# Progressive alignment 1/2...
# STEP   601 / 699 (thread    0)
# Reallocating..done. *alloclen = 1580
#
# done.
#
# Making a distance matrix from msa..
#   600 / 700 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   690 / 700
# done.
#
# Progressive alignment 2/2...
# STEP   601 / 699 (thread    0)
# Reallocating..done. *alloclen = 1591
#
# done.
#
# disttbfast (nuc) Version 7.520
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 1 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: FastTree -quote -nt /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/def188a9-7d0b-4dbc-907c-fae720fd3c1f/data/aligned-dna-sequences.fasta
#
# FastTree Version 2.1.11 Double precision (No SSE3)
# Alignment: /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/def188a9-7d0b-4dbc-907c-fae720fd3c1f/data/aligned-dna-sequences.fasta
# Nucleotide distances: Jukes-Cantor Joins: balanced Support: SH-like 1000
# Search: Normal +NNI +SPR (2 rounds range 10) +ML-NNI opt-each=1
# TopHits: 1.00*sqrtN close=default refresh=0.80
# ML Model: Jukes-Cantor, CAT approximation with 20 rate categories
# Initial topology in 0.29 seconds0 of    680
# Refining topology: 38 rounds ME-NNIs, 2 rounds ME-SPRs, 19 rounds ML-NNIs
# Total branch-length 23.512 after 1.55 sec 1301 of 1364 nodes
# ML-NNI round 1: LogLk = -35940.445 NNIs 136 max delta 16.94 Time 2.26ges (max delta 16.942)
# Switched to using 20 rate categories (CAT approximation)7 of 20
# Rate categories were divided by 1.146 so that average rate = 1.0
# CAT-based log-likelihoods may not be comparable across runs
# Use -gamma for approximate but comparable Gamma(20) log-likelihoods
# ML-NNI round 2: LogLk = -29636.544 NNIs 77 max delta 4.95 Time 2.77nges (max delta 4.947)
# ML-NNI round 3: LogLk = -29585.729 NNIs 41 max delta 4.72 Time 3.08nges (max delta 4.720)
# ML-NNI round 4: LogLk = -29564.812 NNIs 15 max delta 3.70 Time 3.27nges (max delta 3.700)
# ML-NNI round 5: LogLk = -29561.566 NNIs 6 max delta 0.85 Time 3.37
# ML-NNI round 6: LogLk = -29561.532 NNIs 0 max delta 0.00 Time 3.40
# Turning off heuristics for final round of ML NNIs (converged)
# ML-NNI round 7: LogLk = -29536.380 NNIs 16 max delta 1.95 Time 3.99 (final)x delta 1.947)
# Optimize all lengths: LogLk = -29535.828 Time 4.12
# Total time: 4.92 seconds Unique: 683/700 Bad splits: 1/680 Worst delta-LogLk 0.185
# Saved FeatureData[AlignedSequence] to: analysis/tree/aligned_16s_representative_seqs.qza
# Saved FeatureData[AlignedSequence] to: analysis/tree/masked_aligned_16s_representative_seqs.qza
# Saved Phylogeny[Unrooted] to: analysis/tree/16s_unrooted_tree.qza
# Saved Phylogeny[Rooted] to: analysis/tree/16s_rooted_tree.qza

# %%
#Section 4: Basic visualisations and statistics
#ASV relative abundance bar charts

# %%
#Create bar charts to compare the relative abundance of ASVs across samples.

# %%
# !qiime taxa barplot \
--i-table analysis/taxonomy/16s_table_filtered.qza \
--i-taxonomy analysis/taxonomy/classification.qza \
--m-metadata-file data_files/metadata.tsv \
--o-visualization analysis/visualisations/barchart.qzv \
--verbose
# Out:
# Saved Visualization to: analysis/visualisations/barchart.qzv

# %%
path_to_barchart_qzv = 'analysis/visualisations/barchart.qzv'
visualization_barchart = Visualization.load(path_to_barchart_qzv)
display(visualization_barchart)
# Out:
# <visualization: Visualization uuid: f12921fc-62bd-4ca5-9cb9-cce17ad666e2>

# %%
#Rarefaction curves

# !qiime diversity alpha-rarefaction \
--i-table analysis/taxonomy/16s_table_filtered.qza \
--i-phylogeny analysis/tree/16s_rooted_tree.qza \
--p-max-depth 9062 \
--m-metadata-file data_files/metadata.tsv \
--o-visualization analysis/visualisations/16s_alpha_rarefaction.qzv \
--verbose
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/84666e8e-d24b-469c-9b40-21f24e6ff11f/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-pbqv10gq
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/cde26a3e-433f-4820-a6b5-bb472ab2d611/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-zpl2j0qc
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/2322f492-5d61-4248-9d55-36834ea416ed/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-4d8bh1ds
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/1b49351a-12ae-4e4f-a9bf-e54f58b463bc/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-9qi8gxdr
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/60088f34-25c7-4b13-a805-ce471a90e404/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-bk5y01gs
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/03a9bf68-e294-4261-9c75-46144d968fb3/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-uvf8amom
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/52d6f9d3-613a-40f1-ab2d-0cf16312c3d5/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-pu9lo82h
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/43d1247c-153b-4a4e-bdcf-caa4a0856761/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-4o367avn
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/36070a73-be5d-449a-8c6e-3cc8720a6671/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-9dd5sq99
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/73bdc7cf-dc34-4b3c-9d84-e30987b73c69/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-sik_j07q
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/90df2e15-e60a-4c86-b99f-a8d20b3f9b0f/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-urmdvjs8
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/e7100321-5704-479a-8db1-3f727efc521e/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-n42vcp89
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/dde52d67-77b1-412e-a20a-bd246b0448df/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-w1h9zr1c
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f54652b3-24d5-49d5-9f36-f2661bcec89b/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-2rcyj8iv
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/dbd9ae3f-d4c7-4d55-9fbb-26bcf74d8f11/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-tj_5g1kd
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/2a1e3fd3-c2a0-4a93-ac0b-8da9601a2d26/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-2jg669qx
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/28fda918-d60e-4ea5-940a-31b55854e3b8/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-9qfsu0mr
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/bbd2df34-bc1e-46ae-8e7c-aa19f0d52219/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-rlmlvzym
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/0f77691c-ec06-46a6-9067-192e1102fb1b/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-f97na0vc
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f89200e1-6bd7-420a-9eda-51fc91088b31/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-hdes796h
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/a0ae3f89-4e5e-4a22-994e-006f94ded3c9/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-_bhjfsso
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/0473a7cf-2919-43f3-a092-433fed16839a/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-ary527m_
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/a4359223-814e-4718-bc67-b16279e10922/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-m4t17f5g
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/394678d9-0878-4ad5-8200-bfa4ab0e1d69/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-9boyyfyo
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/5023d5db-16bb-4b38-8f2c-92350b39988f/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-vx1l3zvu
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/af625abb-674c-4a5e-90b5-d62ae9f5a8ff/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-8xko4rz2
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/5852c85a-36f4-41d6-8726-7e397f3be564/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-ny8g0s2q
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f7ae4058-b5a2-46d7-bb4f-21b128749c7f/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-_e3fvp8g
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/e97d9045-e97c-46b1-8e12-b3e8da585144/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-c9kbez6m
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/dc41378e-3a97-4c7c-828a-8429ea15d51f/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-iqfp9dl3
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/67457d88-4f7c-4b9e-9df2-673617b552f9/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-2_vn7k01
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/a1c54bfa-a313-4e3a-b526-ada0de3dcd29/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-_ldi3dp2
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/95313a43-14a1-489d-8cd8-bb2d1bbc388c/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-n30tvy3h
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/6572a1ad-e5ac-4c46-be6d-565f7c93274c/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-hnx6_bma
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/d4bf8acc-2fb1-4962-92aa-e83ec624af74/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-i0kwgbu4
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f5ca195e-69e2-42d2-a8a2-9607b727f0ff/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-mkl43820
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/1fad532f-91a0-41b2-bc37-0050b601e493/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-0t189ahw
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/4d928ab3-b001-476c-82c7-d3f26ba1e422/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-38vmgijr
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/ca1bcb8e-2153-4fe2-8bd8-03345259e5e5/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-g8fmg5ja
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/a263fcf4-f715-45f9-8621-b5f6f723df72/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-zcue4_wp
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/8711d0db-cd0b-4c9d-82b3-57e629638f8a/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-v9_vath7
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/337cfb32-b218-484f-80dd-af9d0214f848/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-b2q2el8z
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/67a87507-95b6-4c24-a918-fc60c75238fb/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-qzd1hisb
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/032cc766-51f3-45e2-84ca-1d7b587af4c7/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-mjdp0oz1
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/22dd17a0-d4b5-4b07-a012-002af61bf636/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-6wgt53lx
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/8a9ed4b7-4383-43be-8ce6-461a988d0354/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-1sdf6kbb
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/ab1c8548-422e-4371-94b5-0ea5163e3901/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-7y_m6hnm
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/8d1a66c2-ef26-4b24-9866-f34b6e861001/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-1kwoy4xh
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/61defbe0-24ac-4cb6-a5c3-718047b922d2/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-h168181b
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/c92fff23-0ded-4933-ba01-3386d94d5937/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-1ia9okni
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/00dc3719-8980-460c-894f-89d0ae41a985/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-iehvdjl1
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/0401f53d-8815-43cf-a86b-0bd176ea1b6f/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-jjg0xgrr
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/01b75fce-d0cd-4720-8a7e-c5f62f77ec89/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-152m11x9
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/927fb992-8387-4990-8cad-eb38259a88e8/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-4fjp_lv3
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/910edcbe-12d0-4c99-8b86-602d0cf5a7cc/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-b41mkurn
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/2f4e7072-e8eb-4664-96a6-0ebd57d627f1/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-5u8obxko
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/ce41a8f0-e3a0-4565-a3d7-3e07248d4eb8/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-_f3vk7f8
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/51fcbf17-6a22-459e-a8f9-ba97af2672e7/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-tj9g16zg
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/c80e35b0-c1e4-4046-a46a-2f7f620b8e67/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-jb11tf_0
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/aaa3aed9-f9f9-45f2-b631-a79ccbab6317/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-oqu1u8_z
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/06bee33f-aa18-45f0-9c0a-316b37d83d48/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-37aky3rx
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/528fab54-1d96-4fd1-940c-d8a5539c4f86/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-6f3t_pyi
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/cb6ac339-aae4-45fb-8833-34cad5cd9408/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-z9cyrj6o
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/46068a12-4780-471f-a9b1-3c06d8b1d5d8/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-60tay5m0
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/b3d45889-cd85-4b97-9a5f-1aeec2cd8e47/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-z3qw5d18
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/039422a3-52ea-46f2-95b6-6645c290151a/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-g3ziy512
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/e2831cfd-4727-4b8e-94db-3af6257936f7/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-y_ck9u9i
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7a448c35-ab52-429e-b880-da1bdbedbf4e/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-6g9rg926
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/cc370df7-8ee2-4f97-a36d-a8f6b502c2a0/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-f0ipr7iq
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/2f82e207-bf7a-4d79-a549-3b81db82e800/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-3vv89nmv
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/b298ac22-0c26-413a-88fe-9261a10133ef/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-css1bo0m
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7683c178-8baa-4d01-87d7-bdc716f14ef4/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-v0dt3110
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/2f240a3e-79f4-4600-b0f2-aad88d05c1b3/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-zdy4zdnz
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/96e9318c-5df9-4e71-9ce4-16158e59c771/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-3q9xtip4
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/817ef61f-3550-443f-ad71-ff8358ce30fc/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-vpuy1hkn
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/6f135ed8-c173-4c3b-ba40-f31c7c3ed2a5/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-0hc0xuxe
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/21b46fa1-8320-4c50-8e40-e85c48e07aa6/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-es9zd6qp
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/473cf244-32d4-489e-b0ef-340cfc4ae5cf/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-io5xr2av
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/6c85f88d-f75f-471a-93bd-dcf1f5ca43c1/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-oxzhkk87
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/04674671-cf6e-4fca-ad5c-b336d03ebad5/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-o74gp70x
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ...
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/271275d3-214c-453c-b0c7-090605f73501/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-i3e0xdnn
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/759e00db-94bd-465d-a1f5-13eda33c1ba9/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-s5u2hlgp
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/9a9a7af9-7601-487e-9f07-d6d1ffc26f6c/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-xaiyfj_f
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/f1de1d8e-9e0d-42b7-b515-03ee1cfcd53f/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-6x7l48w2
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/35fada1c-3f94-4559-9426-b92e94506097/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-h9bnvify
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/5efb4228-f148-4b27-bf97-6e26e8fff099/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-jfmu23d9
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/5deae329-bf8c-4e3c-8da2-20aa76b64131/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-k8nffz9v
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/4c240695-3cf5-461c-9f62-ae89afc3b18d/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-ubb4lzs7
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/d148e73f-a1eb-433a-8643-fdde5bbc937f/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-1_do1631
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/fdc2ac07-4ccc-49e5-90e4-c5898e55fc9e/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-lvqepyo9
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/0d9eb3b5-df5e-46a2-a3c5-8202a74bfde2/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-ni51l9z3
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/0974c000-7f99-42d8-bf60-7ee3f29d3772/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-v10jmr7h
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c1115ed-47c6-4be7-8451-c97c6c8c0cb9/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-k8hku985
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/fd1578b6-8ade-444d-a287-1e8f1f7faead/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-gymx9tdo
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/18e985b6-fa94-4268-a23b-2e8141df2c1f/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-vrtqi4m1
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/85955b7d-5d72-48d0-830c-e50048f884ca/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-il64mjgo
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# faithpd -i /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/0d912e7e-aa9d-4020-ac07-90b54834015e/data/feature-table.biom -t /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/qiime2/laurenstoeltje/data/7c7ad574-3873-4de6-aa66-64895eca559e/data/tree.nwk -o /var/folders/cb/bxr92qgn10d978brzl0pdtfc0000gn/T/q2-AlphaDiversityFormat-oyzam113
#
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/laurenstoeltje/miniconda3/envs/qiime2-amplicon-2023.9/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# Saved Visualization to: analysis/visualisations/16s_alpha_rarefaction.qzv

# %%
path_to_qzv = '/Users/laurenstoeltje/final_project_668/analysis/visualisations/16s_alpha_rarefaction.qzv'
visualization = Visualization.load(path_to_qzv)
display(visualization)
# Out:
# <visualization: Visualization uuid: e80ee534-aabd-4149-9154-a8df6d555741>

# %%
#Alpha and beta diversity analysis

# %%
# !qiime diversity core-metrics-phylogenetic \
  --i-phylogeny analysis/tree/16s_rooted_tree.qza \
  --i-table analysis/taxonomy/16s_table_filtered.qza \
  --p-sampling-depth 5583 \
  --m-metadata-file data_files/metadata.tsv \
  --output-dir analysis/diversity_metrics
# Out:
# Saved FeatureTable[Frequency] to: analysis/diversity_metrics/rarefied_table.qza
# Saved SampleData[AlphaDiversity] to: analysis/diversity_metrics/faith_pd_vector.qza
# Saved SampleData[AlphaDiversity] to: analysis/diversity_metrics/observed_features_vector.qza
# Saved SampleData[AlphaDiversity] to: analysis/diversity_metrics/shannon_vector.qza
# Saved SampleData[AlphaDiversity] to: analysis/diversity_metrics/evenness_vector.qza
# Saved DistanceMatrix to: analysis/diversity_metrics/unweighted_unifrac_distance_matrix.qza
# Saved DistanceMatrix to: analysis/diversity_metrics/weighted_unifrac_distance_matrix.qza
# Saved DistanceMatrix to: analysis/diversity_metrics/jaccard_distance_matrix.qza
# Saved DistanceMatrix to: analysis/diversity_metrics/bray_curtis_distance_matrix.qza
# Saved PCoAResults to: analysis/diversity_metrics/unweighted_unifrac_pcoa_results.qza
# Saved PCoAResults to: analysis/diversity_metrics/weighted_unifrac_pcoa_results.qza
# Saved PCoAResults to: analysis/diversity_metrics/jaccard_pcoa_results.qza
# Saved PCoAResults to: analysis/diversity_metrics/bray_curtis_pcoa_results.qza
# Saved Visualization to: analysis/diversity_metrics/unweighted_unifrac_emperor.qzv
# Saved Visualization to: analysis/diversity_metrics/weighted_unifrac_emperor.qzv
# Saved Visualization to: analysis/diversity_metrics/jaccard_emperor.qzv
# Saved Visualization to: analysis/diversity_metrics/bray_curtis_emperor.qzv

# %%
cp analysis/diversity_metrics/*.qzv analysis/visualisations

# %%
#Faith Phylogenetic Diversity (a measure of community richness) and evenness metrics

# %%
# !qiime diversity alpha-group-significance \
  --i-alpha-diversity analysis/diversity_metrics/faith_pd_vector.qza \
  --m-metadata-file data_files/metadata.tsv \
  --o-visualization analysis/visualisations/faith-pd-group-significance.qzv
# Out:
# Saved Visualization to: analysis/visualisations/faith-pd-group-significance.qzv

# %%
path_to_faith_pd = 'analysis/visualisations/faith-pd-group-significance.qzv'
visualization_faith_pd = Visualization.load(path_to_faith_pd)
display(visualization_faith_pd)
# Out:
# <visualization: Visualization uuid: 762c0c8f-e51a-45d7-9b5a-6f3300f48441>

# %%
# !qiime diversity alpha-group-significance \
  --i-alpha-diversity analysis/diversity_metrics/evenness_vector.qza \
  --m-metadata-file data_files/metadata.tsv \
  --o-visualization analysis/visualisations/evenness-group-significance.qzv
# Out:
# Saved Visualization to: analysis/visualisations/evenness-group-significance.qzv

# %%
path_to_evenness = 'analysis/visualisations/evenness-group-significance.qzv'
visualization_evenness = Visualization.load(path_to_evenness)
display(visualization_evenness)
# Out:
# <visualization: Visualization uuid: ad7bae4f-9e1b-460c-b2b0-6c14415d2461>

# %%
#PERMANOVA

# %%
path_to_unweighted_unifrac = 'analysis/visualisations/unweighted_unifrac_emperor.qzv'
visualization_unweighted_unifrac = Visualization.load(path_to_unweighted_unifrac)
display(visualization_unweighted_unifrac)
# Out:
# <visualization: Visualization uuid: 55a7574f-b379-46dc-a02a-bb2ed64bb78c>

# %%
# !qiime diversity beta-group-significance \
  --i-distance-matrix analysis/diversity_metrics/unweighted_unifrac_distance_matrix.qza \
  --m-metadata-file data_files/metadata.tsv \
  --m-metadata-column Genotype \
  --o-visualization analysis/visualisations/unweighted-unifrac-genotype-significance.qzv \
  --p-pairwise
# Out:
# Saved Visualization to: analysis/visualisations/unweighted-unifrac-genotype-significance.qzv

# %%
path_to_unweighted_unifrac_genotype = 'analysis/visualisations/unweighted-unifrac-genotype-significance.qzv'
visualization_unweighted_unifrac = Visualization.load(path_to_unweighted_unifrac_genotype)
display(visualization_unweighted_unifrac)
# Out:
# <visualization: Visualization uuid: d5e95f72-e2cf-40a4-8076-e0beea5185ed>

# %%
#Unweighted UniFrac

# %%
# !qiime diversity beta-group-significance \
  --i-distance-matrix analysis/diversity_metrics/unweighted_unifrac_distance_matrix.qza \
  --m-metadata-file data_files/metadata.tsv \
  --m-metadata-column Environment \
  --o-visualization analysis/visualisations/unweighted-unifrac-environment-significance.qzv \
  --p-pairwise

# %%
path_to_unweighted_unifrac_env = 'analysis/visualisations/unweighted-unifrac-environment-significance.qzv'
visualization_unweighted_unifrac = Visualization.load(path_to_unweighted_unifrac_env)
display(visualization_unweighted_unifrac)
# Out:
# <visualization: Visualization uuid: 4a218fe3-4ec1-45ad-b615-ea8d95760e43>

# %%
#Results:
#Substantial decreases in bacterial alpha diversity were observed in all “sterile” anemone genotypes.
#Simpson’s and Shannon’s bacterial diversity also decreased in all anemones, regardless of genotype, with significant reductions in AIMS2 (Shannon’s only), AIMS3 (both Shannon’s and Simpson’s), and AIMS4 (Shannon’s only).
#A total of 13 bacterial families were found in at least three genotypes of control anemones and absent in at least three genotypes of “sterile” anemones.
#Conversely, there were five families that were present in the “sterile” anemones, yet absent in control anemones.
#PERMANOVA results by genotype confirmed that the bacterial community structure varied significantly with the interaction of sample type and environment.

#Analysis of these results suggest that the bacterial diversity and community structure for each of four anemone genotypes was significantly different with a reduction in alpha diversity when anemones were moved from unfiltered seawater into sterile seawater.
